# %% [markdown]
# <a href="https://colab.research.google.com/github/i4njames/Hirely/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 49.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.1-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.1/311.1 kB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 65.6 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
# Import necessary libraries and modules
import torch
from transformers import BertModel, BertTokenizer

# %%
# Load a pre-trained BERT model and tokenizer
model_name = 'bert-base-uncased'
model = BertModel.from_pretrained(model_name)
tokenizer = BertTokenizer.from_pretrained(model_name)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def classify_text_with_bert(text, model, tokenizer):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True)

    with torch.no_grad():
        outputs = model(**inputs)

    # Access the model's classification head logits
    logits = outputs.last_hidden_state

    # Apply softmax to the logits to get probability scores
    probabilities = torch.softmax(logits, dim=1)

    # Get the predicted sentiment class index for each item in the batch
    predicted_classes = torch.argmax(probabilities, dim=1)

    # Convert the tensor of predicted classes to a Python list
    predicted_classes = predicted_classes.tolist()

    return predicted_classes

# %%
def classify_text_with_bert(text, model, tokenizer):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True)

    with torch.no_grad():
        outputs = model(**inputs)

    # Access the model's classification head logits
    logits = outputs.last_hidden_state

    # Apply softmax to the logits to get probability scores
    probabilities = torch.softmax(logits, dim=1)

    # Get the predicted sentiment class index for each item in the batch
    predicted_classes = torch.argmax(probabilities, dim=1)

    # Convert the tensor of predicted classes to a Python list
    predicted_classes = predicted_classes.tolist()

    return predicted_classes

# %%
# Define a function to perform ABSA on text
def perform_absa(text, aspect):
    # Implement aspect extraction logic if needed
    # This can involve using NER or other techniques to identify the aspect in the text
    aspect_text = ["experience", "skills", "education", "achievements", "soft skills", "Projects "]

    # Perform aspect-based sentiment analysis and return the sentiment score
    sentiment_score = results[0]['label']


    return sentiment_score

# %%
# Import the necessary libraries and modules
from transformers import pipeline
def perform_absa(resume_text):
    # Define the sentiment analysis pipeline
    sentiment_pipeline = pipeline("sentiment-analysis")

    # Analyze the sentiment of the entire resume
    results = sentiment_pipeline(resume_text)

    # Extract the sentiment score (label) from the result
    sentiment_score = results[0]['label']

    return sentiment_score

# %%
# Import the necessary libraries and modules
from transformers import pipeline

# Define the sentiment analysis pipeline
sentiment_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading (…)lve/main/config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
import os
import PyPDF2
from transformers import pipeline

# Define a function to perform ABSA on text
def perform_absa(text):
    # Define the sentiment analysis pipeline with a specific model
    sentiment_pipeline = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

    # Split the text into smaller chunks (you can adjust the chunk size as needed)
    chunk_size = 500  # Number of characters per chunk
    chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]

    sentiment_scores = []

    for chunk in chunks:
        # Analyze the sentiment of each chunk
        results = sentiment_pipeline(chunk)

        # Extract the sentiment score from the result
        sentiment_score = results[0]['score']

        sentiment_scores.append(sentiment_score)

    # Calculate the average sentiment score for all chunks
    avg_sentiment_score = sum(sentiment_scores) / len(sentiment_scores)

    return avg_sentiment_score

# Create a list to store the text content and sentiment scores of each resume
resumes_data = []

# Define the directory where the resume PDF files are located
resume_dir = "/content"

# Iterate over files in the directory
for filename in os.listdir(resume_dir):
    if filename.endswith('.pdf'):
        # Form the complete path to the PDF file
        pdf_file = os.path.join(resume_dir, filename)

        # Open and read each PDF file
        with open(pdf_file, "rb") as file:
            pdf_reader = PyPDF2.PdfReader(file)
            text = ""
            for page_num, page in enumerate(pdf_reader.pages):
                text += page.extract_text()

        # Perform ABSA on the resume text
        sentiment_score = perform_absa(text)

        # Append the resume data (score) to the list
        resumes_data.append((filename, sentiment_score))

# Sort resumes by sentiment score in descending order
sorted_resumes = sorted(resumes_data, key=lambda x: x[1], reverse=True)

# Print the ranked list of resumes (without content, just filenames and sentiment scores)
for rank, (filename, score) in enumerate(sorted_resumes, start=1):
    print(f"Rank {rank}: Resume: {filename}, Sentiment Score: {score}")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/669M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Rank 1: Resume: 48037995.pdf, Sentiment Score: 0.5895803843935331
# Rank 2: Resume: 22776912.pdf, Sentiment Score: 0.5449118394600717
# Rank 3: Resume: 20879311.pdf, Sentiment Score: 0.5091099940678653
# Rank 4: Resume: 46260230.pdf, Sentiment Score: 0.5031455812000093
# Rank 5: Resume: 22450718.pdf, Sentiment Score: 0.4958157204091549
# Rank 6: Resume: 52246737.pdf, Sentiment Score: 0.4931601658463478
# Rank 7: Resume: 52618188.pdf, Sentiment Score: 0.48926315270364285
# Rank 8: Resume: 23864648.pdf, Sentiment Score: 0.4869265372936542
# Rank 9: Resume: 57002858.pdf, Sentiment Score: 0.48471965843980963
# Rank 10: Resume: 51363762.pdf, Sentiment Score: 0.4840935170650482
# Rank 11: Resume: 28126340.pdf, Sentiment Score: 0.4775497002734078
# Rank 12: Resume: 23666211.pdf, Sentiment Score: 0.476540927703564
# Rank 13: Resume: 10641230.pdf, Sentiment Score: 0.43673811988397077
# Rank 14: Resume: 21780877.pdf, Sentiment Score: 0.4350659732635205
# Rank 15: Resume: 21283365.pdf, Sentiment Score: 0.40944905235217166
# Rank 16: Resume: 51639418.pdf, Sentiment Score: 0.4080327938903462
# Rank 17: Resume: 23527321.pdf, Sentiment Score: 0.37374451011419296

# %%
# Define a function to perform ABSA on multiple aspects of a resume
def analyze_resume_aspects(resume_text):
    aspects = {
        "Experience": "experience",
        "Skills": {
            "Object-Oriented Programming Language": "object-oriented programming language",
            "Python": "Python",
            "Java": "JAVA",
            "JavaScript": "JavaScript",
            "C++": "C++",
            "Problem-Solving Skills": "problem-solving skills",
            "Analytical Skills": "analytical skills",
            "Communication": "Communication",
            "Adaptability": "Adaptability",
            "Cloud Platforms": "cloud platforms",
            "Databases": "databases",
            "Leadership": "leadership"
        },
        "Education": "education",
        "Achievements": "achievements",
        "Soft Skills": "soft skills",
        "Projects": "projects",
        "Objective": "objective or summary",
        "Certifications": "certifications",
        "Languages": "languages",
        "Hobbies": "hobbies",
        "Publications": "publications",
        "References": "references",
        "Professional Memberships": "professional memberships",
        "Trainings": "trainings",
    }

    aspect_sentiments = {}

    for aspect_name, aspect_key in aspects.items():
        aspect_text = extract_aspect_from_resume(resume_text, aspect_key)
        sentiment = perform_absa(aspect_text)
        aspect_sentiments[aspect_name] = sentiment

    return aspect_sentiments

import re

def extract_aspect_from_resume(resume_text, aspect_key):
    # Use regular expressions or other methods to extract the specific aspect from the resume text
    # Here, we use a simple example using a keyword (aspect_key)
    aspect_matches = re.findall(rf'{aspect_key}:(.*?)(?:\w+:|$)', resume_text, re.DOTALL)

    # Join the extracted text into a single string
    extracted_text = '\n'.join(aspect_matches)

    return extracted_text

# %%
# Filter out resumes with None overall scores
filtered_resumes_data = [(filename, score) for filename, score in resumes_data if score is not None]

# Sort resumes by overall score in descending order (from highest to lowest)
sorted_resumes = sorted(filtered_resumes_data, key=lambda x: x[1], reverse=True)

# Print the ranked list of resumes (without content, just filenames and scores)
for idx, (filename, score) in enumerate(sorted_resumes, start=1):
    print(f"Rank {idx}: Filename: {filename}, Overall Score: {score}")
# Out:
# Rank 1: Filename: 48037995.pdf, Overall Score: 0.5895803843935331
# Rank 2: Filename: 22776912.pdf, Overall Score: 0.5449118394600717
# Rank 3: Filename: 20879311.pdf, Overall Score: 0.5091099940678653
# Rank 4: Filename: 46260230.pdf, Overall Score: 0.5031455812000093
# Rank 5: Filename: 22450718.pdf, Overall Score: 0.4958157204091549
# Rank 6: Filename: 52246737.pdf, Overall Score: 0.4931601658463478
# Rank 7: Filename: 52618188.pdf, Overall Score: 0.48926315270364285
# Rank 8: Filename: 23864648.pdf, Overall Score: 0.4869265372936542
# Rank 9: Filename: 57002858.pdf, Overall Score: 0.48471965843980963
# Rank 10: Filename: 51363762.pdf, Overall Score: 0.4840935170650482
# Rank 11: Filename: 28126340.pdf, Overall Score: 0.4775497002734078
# Rank 12: Filename: 23666211.pdf, Overall Score: 0.476540927703564
# Rank 13: Filename: 10641230.pdf, Overall Score: 0.43673811988397077
# Rank 14: Filename: 21780877.pdf, Overall Score: 0.4350659732635205
# Rank 15: Filename: 21283365.pdf, Overall Score: 0.40944905235217166
# Rank 16: Filename: 51639418.pdf, Overall Score: 0.4080327938903462
# Rank 17: Filename: 23527321.pdf, Overall Score: 0.37374451011419296

# %%
# Define a function to perform ABSA on text
def perform_absa(text):
    # Define the sentiment analysis pipeline with a specific model
    sentiment_pipeline = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

    # Split the text into smaller chunks (you can adjust the chunk size as needed)
    chunk_size = 500  # Number of characters per chunk
    chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]

    sentiment_scores = []

    for chunk in chunks:
        # Analyze the sentiment of each chunk
        results = sentiment_pipeline(chunk)

        # Extract the sentiment score from the result
        sentiment_score = results[0]['score']

        sentiment_scores.append(sentiment_score)

    # Check if sentiment_scores is not empty before calculating the average
    if sentiment_scores:
        # Calculate the average sentiment score for all chunks
        avg_sentiment_score = sum(sentiment_scores) / len(sentiment_scores)
    else:
        # Set a default value if sentiment_scores is empty
        avg_sentiment_score = 0

    return avg_sentiment_score

# %%
def classify_sentiment(sentiment_score, threshold=0.3):
    if sentiment_score < threshold:
        return "Negative"
    elif sentiment_score >= threshold:
        return "Positive"
    else:
        return "Neutral"

# %%
import os
import PyPDF2
from transformers import pipeline

# Define a function to perform ABSA on text
def perform_absa(text):
    # Define the sentiment analysis pipeline with a specific model
    sentiment_pipeline = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

    # Split the text into smaller chunks (you can adjust the chunk size as needed)
    chunk_size = 500  # Number of characters per chunk
    chunks = [text[i:i + chunk_size] for i in range(0, len(text), chunk_size)]

    sentiment_scores = []

    for chunk in chunks:
        # Analyze the sentiment of each chunk
        results = sentiment_pipeline(chunk)

        # Extract the sentiment score from the result
        sentiment_score = results[0]['score']

        sentiment_scores.append(sentiment_score)

    # Check if sentiment_scores is not empty before calculating the average
    if sentiment_scores:
        # Calculate the average sentiment score for all chunks
        avg_sentiment_score = sum(sentiment_scores) / len(sentiment_scores)
    else:
        # Set a default value if sentiment_scores is empty
        avg_sentiment_score = 0

    return avg_sentiment_score

# Define a function to perform aspect analysis on a resume
def analyze_resume_aspects(resume_text):
    aspects = {
    "Experience": ["experience"],
    "Skills": [
        "object-oriented programming language",
        "programming language",
        "HTML",
        "CSS",
        "Python",
        "JAVA",
        "JavaScript",
        "C++",
        "problem-solving skills",
        "analytical skills",
        "Communication",
        "Adaptability",
        "cloud platforms",
        "databases",
        "leadership"
    ],
    "Education": ["education"],
    "Projects": ["projects"],
    "Achievements": ["achievements"],
    "Soft Skills": ["soft skills"],
    "Projects": ["projects"],
    "Objective": ["objective or summary"],
    "Certifications": ["certifications"],
    "Languages": ["languages"],
    "Hobbies": ["hobbies"],
    "Publications": ["publications"],
    "References": ["references"],
    "Trainings": ["trainings"]
}
    aspect_sentiments = {}

    for aspect_name, aspect_keywords in aspects.items():
        aspect_text = extract_aspect_from_resume(resume_text, aspect_keywords)
        sentiment = perform_absa(aspect_text)
        aspect_sentiments[aspect_name] = sentiment

    return aspect_sentiments

def extract_aspect_from_resume(resume_text, aspect_keywords):
    # Extract the aspect text using keyword search
    aspect_text = ""
    for keyword in aspect_keywords:
     if keyword.strip().lower() in resume_text.lower():
        aspect_text += resume_text[resume_text.lower().find(keyword.strip().lower()):]

    return aspect_text

# Create a list to store the text content, sentiment scores, and aspect sentiments of each resume
resumes_data = []

# Define the directory where the resume PDF files are located
resume_dir = "/content"

# Iterate over files in the directory
for filename in os.listdir(resume_dir):
  if filename.endswith('.pdf'):
        # Form the complete path to the PDF file
        pdf_file = os.path.join(resume_dir, filename)

        # Open and read each PDF file
        with open(pdf_file, "rb") as file:
            pdf_reader = PyPDF2.PdfReader(file)
            text = ""
            for page_num, page in enumerate(pdf_reader.pages):
                text += page.extract_text()

        # Perform ABSA and aspect analysis on the resume text
        sentiment_score = perform_absa(text)
        aspect_sentiments = analyze_resume_aspects(text)

        # Append the resume data (filename, sentiment score, and aspect sentiments) to the list
        resumes_data.append((filename, sentiment_score, aspect_sentiments))

# Sort resumes by sentiment score in descending order
sorted_resumes = sorted(resumes_data, key=lambda x: x[1], reverse=True)

# Print the ranked list of resumes (with content, filenames, sentiment scores, and aspect sentiments)
for rank, (filename, score, aspect_sentiments) in enumerate(sorted_resumes, start=1):
    print(f"Rank {rank}: Resume: {filename}, Sentiment Score: {score}, Aspect Sentiments: {aspect_sentiments}")
# Out:
# Rank 1: Resume: 52246737.pdf, Sentiment Score: 0.4931601658463478, Aspect Sentiments: {'Experience': 0.48858676478266716, 'Skills': 0, 'Education': 0.33772012591362, 'Projects': 0.4171048328280449, 'Achievements': 0, 'Soft Skills': 0, 'Objective': 0, 'Certifications': 0, 'Languages': 0, 'Hobbies': 0, 'Publications': 0, 'References': 0, 'Trainings': 0}
# Rank 2: Resume: 52618188.pdf, Sentiment Score: 0.48926315270364285, Aspect Sentiments: {'Experience': 0.5052957875388009, 'Skills': 0.5027079861611128, 'Education': 0.4155232161283493, 'Projects': 0, 'Achievements': 0, 'Soft Skills': 0, 'Objective': 0, 'Certifications': 0, 'Languages': 0, 'Hobbies': 0, 'Publications': 0, 'References': 0, 'Trainings': 0}
# Rank 3: Resume: 57002858.pdf, Sentiment Score: 0.48471965843980963, Aspect Sentiments: {'Experience': 0.518742867491462, 'Skills': 0.4855661310932853, 'Education': 0.5187604327996572, 'Projects': 0.5351953549044473, 'Achievements': 0, 'Soft Skills': 0, 'Objective': 0, 'Certifications': 0, 'Languages': 0, 'Hobbies': 0, 'Publications': 0, 'References': 0, 'Trainings': 0}
# Rank 4: Resume: 51639418.pdf, Sentiment Score: 0.4080327938903462, Aspect Sentiments: {'Experience': 0.43121730983257295, 'Skills': 0.39847285983463127, 'Education': 0.42307740449905396, 'Projects': 0.37942372635006905, 'Achievements': 0, 'Soft Skills': 0, 'Objective': 0, 'Certifications': 0, 'Languages': 0.37593895196914673, 'Hobbies': 0, 'Publications': 0, 'References': 0, 'Trainings': 0}
